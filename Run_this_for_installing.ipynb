# %%
! pip install numpy
# Out:
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.0 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/61.0 kB 330.3 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/61.0 kB 326.8 kB/s eta 0:00:01
#      -------------------------------------- 61.0/61.0 kB 406.4 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/15.5 MB 3.4 MB/s eta 0:00:05
#    ---------------------------------------- 0.1/15.5 MB 1.8 MB/s eta 0:00:09
#     --------------------------------------- 0.2/15.5 MB 2.0 MB/s eta 0:00:08
#     --------------------------------------- 0.2/15.5 MB 2.0 MB/s eta 0:00:08
#     --------------------------------------- 0.3/15.5 MB 1.4 MB/s eta 0:00:11
#     --------------------------------------- 0.4/15.5 MB 1.5 MB/s eta 0:00:11
# ...

# %%
! pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/162.8 kB ? eta -:--:--
#      ------- ------------------------------- 30.7/162.8 kB 1.4 MB/s eta 0:00:01
#      ---------------------------- --------- 122.9/162.8 kB 1.8 MB/s eta 0:00:01
#      -------------------------------------- 162.8/162.8 kB 1.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.7 MB ? eta -:--:--
#    ---------------------------------------- 0.1/7.7 MB 1.3 MB/s eta 0:00:06
#     --------------------------------------- 0.2/7.7 MB 1.5 MB/s eta 0:00:05
#    - -------------------------------------- 0.2/7.7 MB 1.9 MB/s eta 0:00:04
#    - -------------------------------------- 0.3/7.7 MB 1.8 MB/s eta 0:00:05
#    - -------------------------------------- 0.3/7.7 MB 1.7 MB/s eta 0:00:05
#    - -------------------------------------- 0.4/7.7 MB 1.3 MB/s eta 0:00:06
#    -- ------------------------------------- 0.5/7.7 MB 1.3 MB/s eta 0:00:06
# ...

# %%
! pip install tensorflow
# Out:
# ...
#      ---------------------------------------- 0.0/46.2 kB ? eta -:--:--
#      ---------------------------------------- 46.2/46.2 kB 1.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/377.1 MB ? eta -:--:--
#    ---------------------------------------- 0.1/377.1 MB 2.6 MB/s eta 0:02:23
#    ---------------------------------------- 0.2/377.1 MB 3.1 MB/s eta 0:02:03
#    ---------------------------------------- 0.3/377.1 MB 2.7 MB/s eta 0:02:19
#    ---------------------------------------- 0.4/377.1 MB 2.3 MB/s eta 0:02:44
#    ---------------------------------------- 0.5/377.1 MB 2.4 MB/s eta 0:02:36
#    ---------------------------------------- 0.6/377.1 MB 2.5 MB/s eta 0:02:31
#    ---------------------------------------- 0.7/377.1 MB 2.4 MB/s eta 0:02:40
#    ---------------------------------------- 0.9/377.1 MB 2.4 MB/s eta 0:02:36
#    ---------------------------------------- 1.0/377.1 MB 2.6 MB/s eta 0:02:24
# ...

# %%
! pip install keras

# %%
# Librerie per visualizzare i grafi computazionali (visualizzazione grafica della rete)
# (opzionale - in windows bisogna installare graphviz anche: https://graphviz.gitlab.io/_pages/Download/Download_windows.html)
! pip install pydot
! pip install graphviz

# %% [markdown]
# Ciao
